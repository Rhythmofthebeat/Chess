# %% [markdown]
# <a href="https://colab.research.google.com/github/Rhythmofthebeat/Chess/blob/main/Rhythm_Bazari_Student_NLPForFinance_Section2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color="#de3023"><h1><b>REMINDER MAKE A COPY OF THIS NOTEBOOK, DO NOT EDIT</b></h1></font>

# %% [markdown]
# # **NLP for Finance: Advanced Models**

# %% [markdown]
# <img src="https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=750&q=80%20750w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1050&q=80%201050w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1350&q=80%201350w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1500&q=80%201500w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1650&q=80%201650w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1950&q=80%201950w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2100&q=80%202100w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2250&q=80%202250w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2550&q=80%202550w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2700&q=80%202700w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2850&q=80%202850w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=3150&q=80%203150w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=3300&q=80%203300w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=3450&q=80%203450w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=3750&q=80%203750w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=3900&q=80%203900w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=4000&q=80%204000w" alt="drawing" width="800"/>

# %% [markdown]
# <font color="#de3023"><h5><b>**NOTE:** We'll need to use a GPU for this notebook. Go to "Runtime" -> "Change runtime type" -> and set Hardware Accelerator to "GPU."</b></h5></font>

# %% [markdown]
# What more can you do with your data? Often times, you are given a dataset and must utilize a variety of ML techniques to most effectively create a successful model. Here, we build off our model from notebook 1 using more advanced NLP techniques on the same stock market news dataset. However, these advanced techinques capture more underlying features of our dataset and give us the capacity to arrive at more intelligently inspired sentiment categorizations.

# %% [markdown]
# ## Goals
# In this notebook we will be:
# *   Understanding LSTM model basics.
# *   Building and evaluating an LSTM model from processed data.
# *   Carrying out hyperparameter optimization to improve our model.

# %% [markdown]
# # **Milestone 1: Understanding LSTM model basics.**

# %% [markdown]
# ### **Understanding the Problem: Sentence Word Order**

# %% [markdown]
# The first, greatest hurdle in the world of NLP is transforming our text input into computational data. You have experienced this first-hand in the notebook 1, utilizing Bag-of-Words to generate these representations.
#
# Another great hurdle in the world of NLP is to effectively capture sentence structure and word order. The order of words can completely change the meaning and sentiment of a sentence! Consider sentences **A** and **B** below that are composed of the same exact words and determine whether they have **positive**, **negative**, or **neutral** sentiment.

# %% [markdown]
# ![Screen Shot 2021-06-17 at 4.58.13 PM.png](data:image/png;base64,...)

# %%
#@title Exercise. Sentence Sentiment? { display-mode: "form" }

#@markdown What sentiment would you assign Sentence A?
A  = "negative" #@param ["positive", "negative", "neutral", ""]

#@markdown What sentiment would you assign Sentence B?
B = 'positive' #@param ["positive", "negative", "neutral", ""]


if A == "negative":
  print("Yes, since the company did not profit you can interpret this as being negative! You could also interpret it as neutral.")
elif A == "neutral":
  print("Yes, since the company did not profit you can interpret this as being neutral! You could also interpret it as negative.")
else:
  print('Not quite the right sentiment!')
if B == "positive":
  print("Yes, since the company made significant profits you can interpret that as being positive!")
else:
  print('Not quite the right sentiment!')
# Out:
# Yes, since the company did not profit you can interpret this as being negative! You could also interpret it as neutral.
# Yes, since the company made significant profits you can interpret that as being positive!

# %% [markdown]
# #### **Discussion Exercise: The Impact of Word Order**
#
# How does the order of words impact the meaning of a sentence? Could this pose a problem for our existing sentiment classification model?

# %% [markdown]
# There are countless ways to form sentences given a set of distinct words. We should certainly keep this in our minds as we create more advanced NLP models.

# %% [markdown]
# ### **Solving the Problem: Capturing Word Order**
#
# To understand the effect of word order on our model and how we will tackle it, we need to refresh our memory on how our computational representations of text are created. In the first notebook, we first cleaned the data of stopwords. Afterwards, we used the Bag of Words (BOW) model to generate a vector representation of a given sentence. Let us take a look at the BOW vector representations for Sentences **A** and **B** from above.

# %% [markdown]
# ![Screen Shot 2021-06-17 at 5.48.30 PM.png](data:image/png;base64,...)

# %% [markdown]
# What do you notice about these word vectors? That's right, they're identical! How will our sentiment classification model distinguish between these sentences if they have the same vector representations?

# %%
#@title Exercise. Brainstorm some ways you can capture word order in your model?
Method_1 = 'Assign Numbers' #@param {type:"string"}
Method_2 = 'Bag of Words' #@param {type:"string"}

# %% [markdown]
# We will be using a very advanced NLP architecture called an LSTM. Just as with any standard NLP procedure, we need to capture some numerical representation of our text. However, instead of treating the sentence of words as a bag, we treat them as a sequence!

# %% [markdown]
# ![Screen Shot 2021-06-17 at 6.03.33 PM.png](data:image/png;base64,...)

# %% [markdown]
# Instead of immediately generating a sentence-level representation given the frequency of words, we will tackle the process of generating a representation more iteratively with LSTMs. Imagine starting with an empty vector representation for the sentence of size 256 called **C**

# %% [markdown]
# ![Screen Shot 2021-06-17 at 6.36.48 PM.png](data:image/png;base64,...)

# %% [markdown]
# We start **R** at the beginning of the sentence sequence and iterate it through each of the words. Every time we arrive at a word, we update the **C** vector intelligently to capture sentence structure, the current word, and more.

# %% [markdown]
# This brings us to the very definition of LSTM. LSTM stands for long short-term memory network. It learns the long-term dependencies in a sentence through this sequence-level interpretation. Thus, we pass our vector **C** through the sequence and learn some long term representation **C*** of our sentence. Each word and the words directly before it are what we refer to as the short term memory part of the LSTM.

# %% [markdown]
# ![Screen Shot 2021-06-17 at 6.37.23 PM.png](data:image/png;base64,...)

# %% [markdown]
# # **Milestone 2: Building and evaluating an LSTM model from processed data.**

# %%
#@title Run this to load the datasets and setup the environment. { display-mode: "form" }
# Run this every time you open the spreadsheet
import sys
import os

class HiddenPrints:
    def __enter__(self):
        self._original_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')

    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout.close()
        sys.stdout = self._original_stdout

with HiddenPrints():
  # %load_ext autoreload
  # %autoreload 2
  from collections import Counter
  from importlib.machinery import SourceFileLoader
  import numpy as np
  from os.path import join
  import warnings
  warnings.filterwarnings("ignore")
  from torchtext.vocab import GloVe
  import nltk
  nltk.download('punkt', quiet=True)
  import seaborn as sns
  import matplotlib

  from nltk.tokenize import sent_tokenize, word_tokenize
  from nltk.stem.wordnet import WordNetLemmatizer
  from nltk.stem.porter import *
  from nltk.corpus import stopwords
  nltk.download('stopwords', quiet=True)
  from sklearn.feature_extraction.text import CountVectorizer
  from sklearn.linear_model import LogisticRegression
  from sklearn.model_selection import train_test_split
  import pandas as pd
  from sklearn.metrics import multilabel_confusion_matrix
  from sklearn import metrics
  import gdown
  import string
  import numpy
  import matplotlib.pyplot as plt

  import numpy as np
  import pandas as pd
  import matplotlib.pyplot as plt
  import seaborn as sns
  # !pip install Keras-Preprocessing
  from keras.preprocessing.text import Tokenizer
  from keras_preprocessing.sequence import pad_sequences
  from keras.models import Sequential
  from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
  from sklearn.model_selection import train_test_split
  from keras.utils.np_utils import to_categorical
  from keras.callbacks import EarlyStopping
  from keras.layers import Dropout
  import re
  from nltk.corpus import stopwords
  from nltk import word_tokenize
  STOPWORDS = set(stopwords.words('english'))
  from bs4 import BeautifulSoup

  from keras.preprocessing.text import Tokenizer
  import string

  from sklearn.metrics import confusion_matrix

  # !wget -q --show-progress 'https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20NLP%2BFinance/finance_test.csv'
  # !wget -q --show-progress 'https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20NLP%2BFinance/finance_train.csv'

def plot_confusion_matrix(y_true,y_predicted):
  cm = metrics.confusion_matrix(y_true, y_predicted)
  print ("Plotting the Confusion Matrix")
  labels = ["Negative","Neutral","Positive"]
  df_cm = pd.DataFrame(cm,index =labels,columns = labels)
  fig = plt.figure(figsize=(7,6))
  res = sns.heatmap(df_cm, annot=True,cmap='Blues', fmt='g')
  plt.yticks([0.5,1.5,2.5], labels,va='center')
  plt.title('Confusion Matrix - TestData')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()
  plt.close()


def get_finance_train():
  df_train = pd.read_csv("finance_train.csv")
  return df_train
def get_finance_test():
  df_test = pd.read_csv("finance_test.csv")
  return df_test

PUNCTUATION = '!#$%&()*,-./:;<=>?@^_`{|}~'

REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def clean_text(text):
    """
        text: a string
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text. substitute the matched string in REPLACE_BY_SPACE_RE with space.
    text = BAD_SYMBOLS_RE.sub('', text) # remove symbols which are in BAD_SYMBOLS_RE from text. substitute the matched string in BAD_SYMBOLS_RE with nothing.
    # text = text.replace('x', '')
#    text = re.sub(r'\W+', '', text)
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # remove stopwords from text
    return text

def pad_sequences_train(df_train, df_test):
  tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
  tokenizer.fit_on_texts(df_train['Sentence'].values)
  word_index = tokenizer.word_index
  X = tokenizer.texts_to_sequences(df_train['Sentence'].values)
  X_train = pad_sequences(X, maxlen=MAX_SEQUENCE_LENGTH)
  return X_train

def pad_sequences_test(df_train, df_test):
  tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
  tokenizer.fit_on_texts(df_train['Sentence'].values)
  word_index = tokenizer.word_index
  X = tokenizer.texts_to_sequences(df_test['Sentence'].values)
  X_test = pad_sequences(X, maxlen=MAX_SEQUENCE_LENGTH)
  return X_test

df_train2 = get_finance_train()
df_test2 = get_finance_test()
df_train2['Sentence'] = df_train2['Sentence'].apply(clean_text)
df_test2['Sentence'] = df_test2['Sentence'].apply(clean_text)
def run_model(X_train, y_train, X_test, y_test, epochs=5, batch_size=64, max_sequence_length=256, max_nb_words=1000, embedding_dim=300):
  if any(x is None for x in [X_train, y_train, X_test, y_test, epochs, max_sequence_length, max_nb_words, embedding_dim]):
    print('Replace the None values above with your new values before calling the run_model() function.')
    return None, None, None
  def pad_seq_train(df_train, df_test, max_seq):
    tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
    tokenizer.fit_on_texts(df_train['Sentence'].values)
    word_index = tokenizer.word_index
    X = tokenizer.texts_to_sequences(df_train['Sentence'].values)
    X_train = pad_sequences(X, maxlen=max_seq)
    return X_train
  def pad_seq_test(df_train, df_test, max_seq):
    tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
    tokenizer.fit_on_texts(df_train['Sentence'].values)
    word_index = tokenizer.word_index
    X = tokenizer.texts_to_sequences(df_test['Sentence'].values)
    X_test = pad_sequences(X, maxlen=max_seq)
    return X_test
  X_train2 = pad_seq_train(df_train2, df_test2, max_sequence_length)
  X_test2 = pad_seq_test(df_train2, df_test2, max_sequence_length)
  model = Sequential()
  model.add(Embedding(max_nb_words+1, embedding_dim, mask_zero=True, input_length=max_sequence_length))
  model.add(SpatialDropout1D(0.2))
  model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
  model.add(Dense(n_labels, activation='softmax'))
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  print(model.summary())
  history = model.fit(X_train2,
                    y_train,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_split=0.1,
                    callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)])
  test_loss, test_accuracy = model.evaluate(X_test, y_test)
  return model, history, test_accuracy


EMBEDDING_DIM = 300

plt.rcParams.update({'font.size': 22})

nltk.download('wordnet', quiet=True)

print ("Train & Test Files are loaded")

# %% [markdown]
# ### **Exploring the Datasets**
#
# Before we build our advanced model, let us first read in the data to explore. We will also take a look at a way to process our data even more to further improve the task.

# %% [markdown]
# Here, we'll load in both our training and testing sets from Section 1:

# %%
df_train = get_finance_train()
df_test = get_finance_test()

# %% [markdown]
# Run the 2 cells below to display both datasets and their length:

# %%
print(len(df_train))
df_train.head()

# %%
print(len(df_test))
df_test.head()

# %% [markdown]
# #### **Coding Exercise (Optional): Longest Sentence**
#
# Find and print the length of the longest sentence in this dataset.

# %%
### YOUR CODE HERE

### END CODE

# %% [markdown]
# ### **Data Preprocessing**
#
# To effectively utilize an LSTM, we need to carry out some more data preprocessing. In addition to the preprocessing in the previous notebook, we want to carry out these additional filters to properly create our representations:
#
#
#
# *   Clean our text by removing punctuation marks.
# *   Encoded our text into vectors of _uniform length_. To do this we will _pad_ our sentences.

# %%
#@title Run this cell to clean all the sentences in Finance Train and Finance Test.
#@markdown This will essentially remove our stopwords and punctuation marks.

df_train['Sentence'] = df_train['Sentence'].apply(clean_text)
df_test['Sentence'] = df_test['Sentence'].apply(clean_text)

# %% [markdown]
# #### **Padding Sequences**
#
# To ensure that we can properly create a representation using an LSTM, we need to perform an operation referred to as sentence padding. In standard non-language datasets, you will always have the same number of features for each example. However, that may not always be the case with sentence data if we treat it as a sequence of words. Some sentences will be longer than others! Consider the example sentences that compose your training data below. If each of these words contributes as a feature, it would be weird to have some rows with more features than others.

# %% [markdown]
# ![Screen Shot 2021-06-18 at 4.58.11 PM.png](data:image/png;base64,...)

# %% [markdown]
# So, we will resolve that by adding empty features, or what is referred to as the padding, to smaller sentences such that all sentences will be the same length!

# %% [markdown]
# ![Screen Shot 2021-06-18 at 4.58.51 PM.png](data:image/png;base64,...)

# %% [markdown]
# We will capture this property of the length that we want all the sequences to be padded to in a variable called `MAX_SEQUENCE_LENGTH` and will set it to `256` to be able to capture sentences of maximum length `256` in our model.

# %%
MAX_SEQUENCE_LENGTH = 256

# %% [markdown]
# In addition to a max sequence length, we want to tell our LSTM model how many possible words in the vocab it should expect to properly create our representation. We will save this value in a variable named `MAX_NB_WORDS`, set it equal to `1000`, and pass it to our LSTM model.

# %%
MAX_NB_WORDS = 1000

# %% [markdown]
# #### **Coding Exercise: Padding the Sequences - Training Dataset**
#
# Call the `pad_sequences_train(df_train, df_test)` method while passing in `df_train` and `df_test` as shown and save the result in a variable named `X_train`. Thereafter, print the shape of the `numpy` array and then print the first element using `X_train[0]`. Comment on what you see!

# %%
### YOUR CODE HERE

### END CODE

# %% [markdown]
# #### **Coding Exercise: Padding the Sequences - Testing Dataset**
#
# Call the `pad_sequences_test(df_train, df_test)` method while passing in `df_train` and `df_test` as shown and save the result in a variable named `X_test`. Thereafter, print the shape of the `numpy` array.

# %%
### YOUR CODE HERE

### END CODE

# %% [markdown]
# #### **Coding Exercise: Creating y Dummy Variables - Training Dataset**
#
# The original $y$ labels are given as integers. However, we want to convert these to one-hot encoded vectors of length 3 to signify which of the labels for each of the examples we would assign. This will allow us to learn probabilistic interpretations of the output predictions to best classify the sentences with our LSTM model.

# %% [markdown]
# ![Screen Shot 2021-06-18 at 5.10.01 PM.png](data:image/png;base64,...)

# %% [markdown]
# To do so, we will use a `pandas` function called `get_dummies()`. Call this function on the `Label` column of `df_train` and save the returned value in a variable named `y_train` as follows:
#
#   `y_train = pd.get_dummies(COLUMN).values`
#
# Remember to replace `COLUMN` with the Label columns of the `df_train` matrix. Afterwards, print the shape of y_train.

# %%
### YOUR CODE HERE

### END CODE

# %% [markdown]
# #### **Coding Exercise: Creating y Dummy Variables - Testing Dataset**
#
# Perform the same operation from above, but this time on the `df_test` dataframe. Save it in a variable named `y_test` and print out its shape.

# %%
### YOUR CODE HERE

### END CODE

# %% [markdown]
# ### **Setup and Run Your Model**
#
# We finally have all the data pieces in place to create our model! The last parameter we have in the freedom to optimize in our network is the dimension of each of the word's representations. As we saw above, as we moved through the sequence with the LSTM, we updated the entire sequence's representation based on the individual words.
#
# We will keep track of the number of labels and a map from the label integer to the meanings in variables `n_labels` and `label_map` below.

# %%
n_labels = 3
label_map = {0 : "negative",
             1 : "neutral",
             2 : "positive"}

# %%
#@title Run this cell to instantiate your model!

model = Sequential()
model.add(Embedding(MAX_NB_WORDS+1, EMBEDDING_DIM, mask_zero=True, input_length=MAX_SEQUENCE_LENGTH))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(n_labels, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())

# %% [markdown]
# #### **Coding Exercise: Train your model!**
#
# We finally have most of the pieces in place to train our model successfully! The final pieces will be to let the model know **how** it should carry out its training procedure with the variables `epochs` and `batch_size`. For now, set the value of `epochs` to be `5` and the value of `batch_size` to be `64` and we will later explore how changing them impacts our results.

# %%
epochs = None ### YOUR CODE HERE
batch_size = None ### YOUR CODE HERE

# %% [markdown]
# Now, we will run our model using the `X_train` and `y_train` variables we created in addition to some other hyperparameters.
#
# **Run the cell below to train your model!**

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_split=0.1,
                    callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)])

# %% [markdown]
# #### **Coding Exercise: Evaluate your model!**
#
# We have saved and trained our model in the variable named `model`. To evaluate our model. we can call the `model.evaluate(X_test, y_test)` function while passing in our test sets as shown. This method will return two values: the **loss** and the **accuracy** on the test set. Call the `model.evaluate()` function and save your results in two variables named `test_loss` and `test_accuracy`. Then, print these variables to assess your model's performance!

# %%
test_loss, test_accuracy = None, None ### YOUR CODE HERE

# %% [markdown]
# #### **Discussion Exercise: Significance of and variability in results**
#
# Share your results with your peers! How well did your model do? Were there any differences between your results and the results of your peers? If so, why do you think this is the case?

# %% [markdown]
# #### **Coding Exercise: Plot your losses!**
#
# When we trained the model above, we saved the output of the call to `model.train()` in a variable named `history`. This variable holds information regarding the training and validation set losses and accuracies over the course of model training. Let us plot these curves and analyze what we see!
#
# First, we will begin by plotting the training and validation losses. To access the training loss, call `history.history["loss"]` and save it in a variable named `training_loss`.

# %%
training_loss = None ### YOUR CODE HERE

# %% [markdown]
# Do the same for your validation loss through calling `history.history["val_loss"]` and save it in a variable named `validation_loss`.

# %%
validation_loss = None ### YOUR CODE HERE

# %% [markdown]
# Now, we will plot both the training and validation losses on the same graph. To do so, call the `plt.plot(LOSS, label="LABEL")` function below twice.
#
# In your first call, replace `LOSS` with your `training_loss` and `LABEL` with `"train"`.
#
# In your second call, replace `LOSS` with your `validation_loss` and `"LABEL"` with `"validation"`.

# %%
fig = plt.figure(figsize=(12,6))
plt.title('Loss over Time')
plt.xlabel('Epochs')
plt.ylabel('Loss')

### YOUR CODE HERE

### END CODE

plt.legend()
plt.show()

# %% [markdown]
# #### **Discussion Exercise: Significance of your loss plots**
#
# What do you notice about your loss plots? Does your plot look strange? If so, why do you think that is?

# %% [markdown]
# #### **Coding Exercise: Plot your accuracies!**
#
# Now, we will begin to plot the training and validation accuracies. To access the training accuracy, call `history.history["accuracy"]` and save it in a variable named `training_accuracy`. Similarly, access the validation accuracy with the call to `history.history["val_accuracy"]` and save it in a variable named `validation_accuracy`.

# %%
training_accuracy = None ### YOUR CODE HERE
validation_accuracy = None ### YOUR CODE HERE

# %% [markdown]
# Now, we will plot both the training and validation accuracies on the same graph. To do so, call the `plt.plot(ACCURACY, label="LABEL")` function below twice.
#
# In your first call, replace `ACCURACY` with your `training_accuracy` and `LABEL` with `"train"`.
#
# In your second call, replace `ACCURACY` with your `validation_accuracy` and `"LABEL"` with `"validation"`.

# %%
fig = plt.figure(figsize=(12,6))
plt.title('Accuracy over Time')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

### YOUR CODE HERE

### END CODE

plt.legend()
plt.show()

# %% [markdown]
# #### **Discussion Exercise: Significance of your accuracy plots**
#
# What do you notice about your accuracy plots? Are these results what you expected?

# %% [markdown]
# # **Milestone 3: Carrying out hyperparameter optimization to improve your model.**
#
# A very important aspect of Machine Learning is tuning our hyperparameters. We can make small tweaks to our model to bring about great impact and beneficial results. You will now have the chance to change some of these hyperparameters and explore what impact this has on the model's accuracy!

# %% [markdown]
# #### **Coding Exercise: Optimize and Run Your Models!**
#
# Try modifying one of the four hyperparameters in the list below from their original values. Each hyperparameter is described briefly with tradeoffs mentioned. However, we want you to run the model again to evaluate your new accuracies!
#
#   * `epochs` : This was originally set to `5`. What will happen if we set it to `10` or `20`? If you set it too high your model will take much longer to run, so keep that in mind!
#   * `MAX_NB_WORDS` : This was the max number of words we assumed the vocabulary would encompass for our model that was originally set to `1000`. Try modifying it to see what changes it gives!
#   * `EMBEDDING_DIM` : Although we did not describe this parameter, it may play an important role in optimizing our model. This represents the dimension of the embedding used for each of the individual words which thereby impacts the learned embedding for each sentence and was originally set to `300`. If we allow for larger embedding dimensions we may be able to capture more granularity in the model at the expense of overfitting. Try modifying this parameter to evaluate its effect on the model!

# %% [markdown]
# To ease the model running process, you can use the simplified function `run_model()` created for you! Simply pass in your `X_train`, `y_train`, `X_test`, `y_test`, and each of the 4 hyperparameters from above.
#
# The `run_model()` method will return 3 variables:
#   1. `model` : This is your trained model.
#   2. `history` : This contains loss and accuracy history over the epochs like before.
#   3. `test_acc` : This is your test set accuracy that you will use to evaluate the success of your model.

# %%
model, history, test_acc = run_model(
    X_train=None, ### YOUR CODE HERE
    y_train=None, ### YOUR CODE HERE
    X_test=None, ### YOUR CODE HERE
    y_test=None, ### YOUR CODE HERE
    epochs=None, ### YOUR CODE HERE
    batch_size=None, ### YOUR CODE HERE
    max_sequence_length=None, ### YOUR CODE HERE
    max_nb_words=None, ### YOUR CODE HERE
    embedding_dim=None ### YOUR CODE HERE
)

# %% [markdown]
# **Try to build the best model that you can!**
#
# Vary parameters of your models and try to get an accuracy above **87%**!

# %% [markdown]
# #### **Coding Exercise (Optional): Plot your new losses and accuracies!**
#
# Using the `history` parameter returned from the `run_model()` function, plot your new training and validation loss/accuracy curves and explore the difference between these and the curves of your original model. What do you notice? What tradeoff did modifying the hyperparameters allow for?

# %%
### YOUR CODE HERE

### END CODE

# %% [markdown]
# #### **Plot the confusion matrix!**
# Let's test our model on the test set, and observe our confusion matrix. Careful inspection of our results often give us useful insights on what kind of mistakes our model is making. Which category does your model particularly struggle on?

# %%
# Predict on our test set
y_prob = model.predict(X_test)
y_pred = y_prob.argmax(axis = - 1)
y_true = y_test.argmax(axis = - 1)

# plot the confusion matrix!
plot_confusion_matrix(y_true, y_pred)

# %% [markdown]
# # Congratulations on completing your advanced LSTM model!

# %% [markdown]
# ## **Wrap-Up**
#
# In this notebook, you've:
#
#  * Learned about LSTMs and the basics of how they work.
#  * Learned how to further preprocess text data to filter punctuation with `regex` and additionally pad input sequences.
#  * Built an Advanced LSTM Model that predicts the sentiment of financial news text segments.
#
#  With this knowledge, you have the capacity to intelligently explore financial and stock-related text domains to extract meaningful sentiment information!
#
#  But, can we improve our models even more..? In the next notebook, we will learn how to capture word and sentence embedding representations even more powerfully and use that to improve our model's accuracy!
#
# <img src="https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=750&q=80%20750w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1050&q=80%201050w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1350&q=80%201350w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1500&q=80%201500w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1650&q=80%201650w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1950&q=80%201950w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2100&q=80%202100w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2250&q=80%202250w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2550&q=80%202550w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2700&q=80%202700w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2850&q=80%202850w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=3150&q=80%203150w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=3300&q=80%203300w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=3450&q=80%203450w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=3750&q=80%203750w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=3900&q=80%203900w,%20https://images.unsplash.com/photo-1504711434969-e33886168f5c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=4000&q=80%204000w" alt="drawing" width="800"/>
